# %% [markdown]
# <a href="https://colab.research.google.com/github/rddelarosa/DSC1107/blob/main/FA_2_DSC1107.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
library(tidyverse)

# %%
who
population <- read_csv("/content/Population.csv", skip=4)
population
# Out:
#      country     iso2 iso3 year new_sp_m014 new_sp_m1524 new_sp_m2534
# 1    Afghanistan AF   AFG  1980  NA          NA           NA
# 2    Afghanistan AF   AFG  1981  NA          NA           NA
# 3    Afghanistan AF   AFG  1982  NA          NA           NA
# 4    Afghanistan AF   AFG  1983  NA          NA           NA
# 5    Afghanistan AF   AFG  1984  NA          NA           NA
# 6    Afghanistan AF   AFG  1985  NA          NA           NA
# 7    Afghanistan AF   AFG  1986  NA          NA           NA
# 8    Afghanistan AF   AFG  1987  NA          NA           NA
# 9    Afghanistan AF   AFG  1988  NA          NA           NA
# 10   Afghanistan AF   AFG  1989  NA          NA           NA
# 11   Afghanistan AF   AFG  1990  NA          NA           NA
# 12   Afghanistan AF   AFG  1991  NA          NA           NA
# 13   Afghanistan AF   AFG  1992  NA          NA           NA
# 14   Afghanistan AF   AFG  1993  NA          NA           NA
# 15   Afghanistan AF   AFG  1994  NA          NA           NA
# 16   Afghanistan AF   AFG  1995  NA          NA           NA
# 17   Afghanistan AF   AFG  1996  NA          NA           NA
# 18   Afghanistan AF   AFG  1997   0          10            6
# 19   Afghanistan AF   AFG  1998  30         129          128
# 20   Afghanistan AF   AFG  1999   8          55           55
# 21   Afghanistan AF   AFG  2000  52         228          183
# 22   Afghanistan AF   AFG  2001 129         379          349
# 23   Afghanistan AF   AFG  2002  90         476          481
# 24   Afghanistan AF   AFG  2003 127         511          436
# 25   Afghanistan AF   AFG  2004 139         537          568
# 26   Afghanistan AF   AFG  2005 151         606          560
# 27   Afghanistan AF   AFG  2006 193         837          791
# 28   Afghanistan AF   AFG  2007 186         856          840
# 29   Afghanistan AF   AFG  2008 187         941          773
# 30   Afghanistan AF   AFG  2009 200         906          705
# ⋮    ⋮           ⋮    ⋮    ⋮    ⋮           ⋮            ⋮
# 7211 Zimbabwe    ZW   ZWE  1984  NA          NA            NA
# 7212 Zimbabwe    ZW   ZWE  1985  NA          NA            NA
# 7213 Zimbabwe    ZW   ZWE  1986  NA          NA            NA
# 7214 Zimbabwe    ZW   ZWE  1987  NA          NA            NA
# 7215 Zimbabwe    ZW   ZWE  1988  NA          NA            NA
# 7216 Zimbabwe    ZW   ZWE  1989  NA          NA            NA
# 7217 Zimbabwe    ZW   ZWE  1990  NA          NA            NA
# 7218 Zimbabwe    ZW   ZWE  1991  NA          NA            NA
# 7219 Zimbabwe    ZW   ZWE  1992  NA          NA            NA
# 7220 Zimbabwe    ZW   ZWE  1993  NA          NA            NA
# 7221 Zimbabwe    ZW   ZWE  1994  NA          NA            NA
# 7222 Zimbabwe    ZW   ZWE  1995  NA          NA            NA
# 7223 Zimbabwe    ZW   ZWE  1996  NA          NA            NA
# 7224 Zimbabwe    ZW   ZWE  1997  NA          NA            NA
# 7225 Zimbabwe    ZW   ZWE  1998  NA          NA            NA
# 7226 Zimbabwe    ZW   ZWE  1999  NA          NA            NA
# 7227 Zimbabwe    ZW   ZWE  2000  NA          NA            NA
# 7228 Zimbabwe    ZW   ZWE  2001  NA          NA            NA
# 7229 Zimbabwe    ZW   ZWE  2002 191         600          2548
# 7230 Zimbabwe    ZW   ZWE  2003 133         874          3048
# 7231 Zimbabwe    ZW   ZWE  2004 187         833          2908
# 7232 Zimbabwe    ZW   ZWE  2005 210         837          2264
# 7233 Zimbabwe    ZW   ZWE  2006 215         736          2391
# 7234 Zimbabwe    ZW   ZWE  2007 138         500          3693
# 7235 Zimbabwe    ZW   ZWE  2008 127         614             0
# 7236 Zimbabwe    ZW   ZWE  2009 125         578            NA
# 7237 Zimbabwe    ZW   ZWE  2010 150         710          2208
# 7238 Zimbabwe    ZW   ZWE  2011 152         784          2467
# 7239 Zimbabwe    ZW   ZWE  2012 120         783          2421
# 7240 Zimbabwe    ZW   ZWE  2013  NA          NA            NA
#      new_sp_m3544 new_sp_m4554 new_sp_m5564 ⋯ newrel_m4554 newrel_m5564
# 1     NA           NA           NA          ⋯ NA           NA
# 2     NA           NA           NA          ⋯ NA           NA
# 3     NA           NA           NA          ⋯ NA           NA
# 4     NA           NA           NA          ⋯ NA           NA
# 5     NA           NA           NA          ⋯ NA           NA
# 6     NA           NA           NA          ⋯ NA           NA
# 7     NA           NA           NA          ⋯ NA           NA
# 8     NA           NA           NA          ⋯ NA           NA
# 9     NA           NA           NA          ⋯ NA           NA
# 10    NA           NA           NA          ⋯ NA           NA
# 11    NA           NA           NA          ⋯ NA           NA
# 12    NA           NA           NA          ⋯ NA           NA
# 13    NA           NA           NA          ⋯ NA           NA
# 14    NA           NA           NA          ⋯ NA           NA
# 15    NA           NA           NA          ⋯ NA           NA
# 16    NA           NA           NA          ⋯ NA           NA
# 17    NA           NA           NA          ⋯ NA           NA
# 18     3            5            2          ⋯ NA           NA
# 19    90           89           64          ⋯ NA           NA
# 20    47           34           21          ⋯ NA           NA
# 21   149          129           94          ⋯ NA           NA
# 22   274          204          139          ⋯ NA           NA
# 23   368          246          241          ⋯ NA           NA
# 24   284          256          288          ⋯ NA           NA
# 25   360          358          386          ⋯ NA           NA
# 26   472          453          470          ⋯ NA           NA
# 27   574          572          572          ⋯ NA           NA
# 28   597          566          630          ⋯ NA           NA
# 29   545          570          630          ⋯ NA           NA
# 30   499          491          596          ⋯ NA           NA
# ⋮    ⋮            ⋮            ⋮            ⋱ ⋮            ⋮
# 7211   NA           NA          NA          ⋯   NA           NA
# 7212   NA           NA          NA          ⋯   NA           NA
# 7213   NA           NA          NA          ⋯   NA           NA
# 7214   NA           NA          NA          ⋯   NA           NA
# 7215   NA           NA          NA          ⋯   NA           NA
# 7216   NA           NA          NA          ⋯   NA           NA
# 7217   NA           NA          NA          ⋯   NA           NA
# 7218   NA           NA          NA          ⋯   NA           NA
# 7219   NA           NA          NA          ⋯   NA           NA
# 7220   NA           NA          NA          ⋯   NA           NA
# 7223   NA         NA          NA           NA           NA           NA
# 7224   NA         NA          NA           NA           NA           NA
# 7225   NA         NA          NA           NA           NA           NA
# 7226   NA         NA          NA           NA           NA           NA
# 7227   NA         NA          NA           NA           NA           NA
# 7228   NA         NA          NA           NA           NA           NA
# 7229   NA         NA          NA           NA           NA           NA
# 7230   NA         NA          NA           NA           NA           NA
# 7231   NA         NA          NA           NA           NA           NA
# 7232   NA         NA          NA           NA           NA           NA
# 7233   NA         NA          NA           NA           NA           NA
# 7234   NA         NA          NA           NA           NA           NA
# 7235   NA         NA          NA           NA           NA           NA
# 7236   NA         NA          NA           NA           NA           NA
# 7237   NA         NA          NA           NA           NA           NA
# 7238   NA         NA          NA           NA           NA           NA
# 7239   NA         NA          NA           NA           NA           NA
# 7240 1208       1252        2069         4649         3526         1453
#      newrel_f5564 newrel_f65
# 1    NA           NA
# 2    NA           NA
# 3    NA           NA
# 4    NA           NA
# 5    NA           NA
# 6    NA           NA
# 7    NA           NA
# 8    NA           NA
# 9    NA           NA
# 10   NA           NA
# 11   NA           NA
# 12   NA           NA
# 13   NA           NA
# 14   NA           NA
# 15   NA           NA
# 16   NA           NA
# 17   NA           NA
# 18   NA           NA
# 19   NA           NA
# 20   NA           NA
# 21   NA           NA
# 22   NA           NA
# 23   NA           NA
# 24   NA           NA
# 25   NA           NA
# 26   NA           NA
# 27   NA           NA
# 28   NA           NA
# 29   NA           NA
# 30   NA           NA
# ⋮    ⋮            ⋮
# 7211  NA           NA
# 7212  NA           NA
# 7213  NA           NA
# 7214  NA           NA
# 7215  NA           NA
# 7216  NA           NA
# 7217  NA           NA
# 7218  NA           NA
# 7219  NA           NA
# 7220  NA           NA
# 7221  NA           NA
# 7222  NA           NA
# 7223  NA           NA
# 7224  NA           NA
# 7225  NA           NA
# 7226  NA           NA
# 7227  NA           NA
# 7228  NA           NA
# 7229  NA           NA
# 7230  NA           NA
# 7231  NA           NA
# 7232  NA           NA
# 7233  NA           NA
# 7234  NA           NA
# 7235  NA           NA
# 7236  NA           NA
# 7237  NA           NA
# 7238  NA           NA
# 7239  NA           NA
# 7240 811          725
# New names:
# • `` -> `...69`
# Rows: 266 Columns: 69
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (4): Country Name, Country Code, Indicator Name, Indicator Code
# dbl (64): 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, ...
# lgl  (1): ...69
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#     Country Name                                         Country Code
# 1   Aruba                                                ABW
# 2   Africa Eastern and Southern                          AFE
# 3   Afghanistan                                          AFG
# 4   Africa Western and Central                           AFW
# 5   Angola                                               AGO
# 6   Albania                                              ALB
# 7   Andorra                                              AND
# 8   Arab World                                           ARB
# 9   United Arab Emirates                                 ARE
# 10  Argentina                                            ARG
# 11  Armenia                                              ARM
# 12  American Samoa                                       ASM
# 13  Antigua and Barbuda                                  ATG
# 14  Australia                                            AUS
# 15  Austria                                              AUT
# 16  Azerbaijan                                           AZE
# 17  Burundi                                              BDI
# 18  Belgium                                              BEL
# 19  Benin                                                BEN
# 20  Burkina Faso                                         BFA
# 21  Bangladesh                                           BGD
# 22  Bulgaria                                             BGR
# 23  Bahrain                                              BHR
# 24  Bahamas, The                                         BHS
# 25  Bosnia and Herzegovina                               BIH
# 26  Belarus                                              BLR
# 27  Belize                                               BLZ
# 28  Bermuda                                              BMU
# 29  Bolivia                                              BOL
# 30  Brazil                                               BRA
# ⋮   ⋮                                                    ⋮
# 237 Latin America & the Caribbean (IDA & IBRD countries) TLA
# 238 Timor-Leste                                          TLS
# 239 Middle East & North Africa (IDA & IBRD countries)    TMN
# 240 Tonga                                                TON
# 241 South Asia (IDA & IBRD)                              TSA
# 242 Sub-Saharan Africa (IDA & IBRD countries)            TSS
# 243 Trinidad and Tobago                                  TTO
# 244 Tunisia                                              TUN
# 245 Turkiye                                              TUR
# 246 Tuvalu                                               TUV
# 247 Tanzania                                             TZA
# 248 Uganda                                               UGA
# 249 Ukraine                                              UKR
# 250 Upper middle income                                  UMC
# 251 Uruguay                                              URY
# 252 United States                                        USA
# 253 Uzbekistan                                           UZB
# 254 St. Vincent and the Grenadines                       VCT
# 255 Venezuela, RB                                        VEN
# 256 British Virgin Islands                               VGB
# 257 Virgin Islands (U.S.)                                VIR
# 258 Viet Nam                                             VNM
# 259 Vanuatu                                              VUT
# 260 World                                                WLD
# 261 Samoa                                                WSM
# 262 Kosovo                                               XKX
# 263 Yemen, Rep.                                          YEM
# 264 South Africa                                         ZAF
# 265 Zambia                                               ZMB
# 266 Zimbabwe                                             ZWE
#     Indicator Name    Indicator Code 1960       1961       1962
# 1   Population, total SP.POP.TOTL        54922      55578      56320
# 2   Population, total SP.POP.TOTL    130072080  133534923  137171659
# 3   Population, total SP.POP.TOTL      9035043    9214083    9404406
# 4   Population, total SP.POP.TOTL     97630925   99706674  101854756
# 5   Population, total SP.POP.TOTL      5231654    5301583    5354310
# 6   Population, total SP.POP.TOTL      1608800    1659800    1711319
# 7   Population, total SP.POP.TOTL         9510      10283      11086
# 8   Population, total SP.POP.TOTL     91540853   93931683   96428599
# 9   Population, total SP.POP.TOTL       131334     137989     144946
# 10  Population, total SP.POP.TOTL     20386045   20726276   21072538
# 11  Population, total SP.POP.TOTL      1863705    1927484    1991689
# 12  Population, total SP.POP.TOTL        20133      20666      21298
# 13  Population, total SP.POP.TOTL        55603      56540      57336
# 14  Population, total SP.POP.TOTL     10276477   10483000   10742000
# 15  Population, total SP.POP.TOTL      7047539    7086299    7129864
# 16  Population, total SP.POP.TOTL      3894500    4045750    4168150
# 17  Population, total SP.POP.TOTL      2764258    2835119    2907943
# 18  Population, total SP.POP.TOTL      9153489    9183948    9220578
# 19  Population, total SP.POP.TOTL      2517286    2559223    2604659
# 20  Population, total SP.POP.TOTL      4778621    4848224    4919672
# 21  Population, total SP.POP.TOTL     51828660   53310348   54881146
# 22  Population, total SP.POP.TOTL      7867374    7943118    8012946
# 23  Population, total SP.POP.TOTL       165477     172346     179349
# 24  Population, total SP.POP.TOTL       116317     122197     128493
# 25  Population, total SP.POP.TOTL      3281381    3348035    3407532
# 26  Population, total SP.POP.TOTL      8198000    8271216    8351928
# 27  Population, total SP.POP.TOTL        91318      93632      96042
# 28  Population, total SP.POP.TOTL        42208      43123      44239
# 29  Population, total SP.POP.TOTL      3702323    3778731    3857493
# 30  Population, total SP.POP.TOTL     72388126   74605447   76865323
# ⋮   ⋮                 ⋮              ⋮          ⋮          ⋮
# 237 Population, total SP.POP.TOTL     208671107  214582669  220668336
# 238 Population, total SP.POP.TOTL        468118     475291     482774
# 239 Population, total SP.POP.TOTL      97138700   99660885  102288730
# 240 Population, total SP.POP.TOTL         66170      68037      69940
# 241 Population, total SP.POP.TOTL     562663671  576552257  590723078
# 242 Population, total SP.POP.TOTL     227703005  233241597  239026415
# 243 Population, total SP.POP.TOTL        844943     863144     880194
# 244 Population, total SP.POP.TOTL       4267288    4316278    4369136
# 245 Population, total SP.POP.TOTL      28329898   29119238   29916147
# 246 Population, total SP.POP.TOTL          5598       5648       5699
# 247 Population, total SP.POP.TOTL       9901419   10187886   10487756
# 248 Population, total SP.POP.TOTL       7640973    7862217    8092231
# 249 Population, total SP.POP.TOTL      42824093   43399766   43943674
# 250 Population, total SP.POP.TOTL    1151246171 1157236371 1175758905
# 251 Population, total SP.POP.TOTL       2529957    2562044    2593298
# 252 Population, total SP.POP.TOTL     180671000  183691000  186538000
# 253 Population, total SP.POP.TOTL       8209109    8517711    8854368
# 254 Population, total SP.POP.TOTL         84388      85870      87236
# 255 Population, total SP.POP.TOTL       8160090    8455915    8756870
# 256 Population, total SP.POP.TOTL          7950       8034       8070
# 257 Population, total SP.POP.TOTL         32500      34300      35000
# 258 Population, total SP.POP.TOTL      32531933   33409059   34288560
# 259 Population, total SP.POP.TOTL         64431      66264      68174
# 260 Population, total SP.POP.TOTL    3021529236 3062769479 3117373096
# 261 Population, total SP.POP.TOTL        112490     115496     118597
# 262 Population, total SP.POP.TOTL        984846    1011421    1036950
# 263 Population, total SP.POP.TOTL       5532301    5655232    5782221
# 264 Population, total SP.POP.TOTL      16440172   16908035   17418522
# 265 Population, total SP.POP.TOTL       3153729    3254086    3358099
# 266 Population, total SP.POP.TOTL       3809389    3930401    4055959
#     1963       1964       1965       ⋯ 2015       2016       2017
# 1       57002      57619      58190  ⋯    107906     108727     108735
# 2   140945536  144904094  149033472  ⋯ 607123269  623369401  640058741
# 3     9604487    9814318   10036008  ⋯  33831764   34700612   35688935
# 4   104089175  106388440  108772632  ⋯ 418127845  429454743  440882906
# 5     5408320    5464187    5521981  ⋯  28157798   29183070   30234839
# 6     1762621    1814135    1864791  ⋯   2880703    2876101    2873457
# 7       11915      12764      13634  ⋯     72174      72181      73763
# 8    99038509  101729760  104494008  ⋯ 410190679  419808341  428315886
# 9      152211     159692     167103  ⋯   8505237    8935095    9223225
# 10   21421705   21769453   22112629  ⋯  43477012   43900313   44288894
# 11    2056023    2120135    2183635  ⋯   3004600    2992300    2979400
# 12      21966      22673      23406  ⋯     52878      52245      51586
# 13      58138      59020      59970  ⋯     89409      89969      90468
# 255   29807592   28938098   28444077   28237826   28213017   28300854 NA
# 256      34657      36395      37135      37809      38319      38985 NA
# 257     107001     106669     106290     105870     105413     104917 NA
# 258   96237319   97173776   98079191   98935098   99680655  100352192 NA
# 259     285259     291985     298858     305868     313046     320409 NA
# 260 7696494848 7776892015 7856138790 7921184346 7989981520 8061876001 NA
# 261     207582     209780     211944     213779     215261     216663 NA
# 262    1797086    1788891    1790152    1786080    1768096    1756366 NA
# 263   34085182   35111408   36134863   37140230   38222876   39390799 NA
# 264   58613001   59587885   60562381   61502603   62378410   63212384 NA
# 265   17973569   18513839   19059395   19603607   20152938   20723965 NA
# 266   15034452   15271368   15526888   15797210   16069056   16340822 NA

# %% [markdown]
# **2. Import**
#
#    2.1. Preview the contents of who.tsv and population.csv by inspecting the files.

# %%
glimpse(who)
glimpse(population)
# Out:
# Rows: 7,240
# Columns: 60
# $ country      <chr> "Afghanistan", "Afghanistan", "Afghanistan", "Afghanistan…
# $ iso2         <chr> "AF", "AF", "AF", "AF", "AF", "AF", "AF", "AF", "AF", "AF…
# $ iso3         <chr> "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "…
# $ year         <dbl> 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 198…
# $ new_sp_m014  <dbl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, N…
# $ new_sp_m1524 <dbl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, N…
# $ new_sp_m2534 <dbl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, N…
# $ new_sp_m3544 <dbl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, N…
# $ new_sp_m4554 <dbl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, N…
# $ new_sp_m5564 <dbl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, N…
# $ new_sp_m65   <dbl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, N…
# $ new_sp_f014  <dbl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, N…
# $ new_sp_f1524 <dbl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, N…
# $ new_sp_f2534 <dbl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, N…
# $ new_sp_f3544 <dbl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, N…
# $ new_sp_f4554 <dbl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, N…
# $ new_sp_f5564 <dbl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, N…
# $ new_sp_f65   <dbl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, N…
# $ new_sn_m014  <dbl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, N…
# $ new_sn_m1524 <dbl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, N…
# $ new_sn_m2534 <dbl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, N…
# $ new_sn_m3544 <dbl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, N…
# $ new_sn_m4554 <dbl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, N…
# $ new_sn_m5564 <dbl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, N…
# $ new_sn_m65   <dbl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, N…
# $ new_sn_f014  <dbl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, N…
# $ new_sn_f1524 <dbl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, N…
# $ new_sn_f2534 <dbl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, N…
# $ new_sn_f3544 <dbl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, N…
# $ new_sn_f4554 <dbl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, N…
# $ new_sn_f5564 <dbl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, N…
# $ new_sn_f65   <dbl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, N…
# $ new_ep_m014  <dbl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, N…
# $ new_ep_m1524 <dbl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, N…
# $ new_ep_m2534 <dbl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, N…
# $ new_ep_m3544 <dbl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, N…
# $ new_ep_m4554 <dbl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, N…
# $ new_ep_m5564 <dbl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, N…
# $ new_ep_m65   <dbl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, N…
# $ new_ep_f014  <dbl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, N…
# $ new_ep_f1524 <dbl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, N…
# $ new_ep_f2534 <dbl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, N…
# $ new_ep_f3544 <dbl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, N…
# $ new_ep_f4554 <dbl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, N…
# $ new_ep_f5564 <dbl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, N…
# $ new_ep_f65   <dbl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, N…
# $ newrel_m014  <dbl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, N…
# $ newrel_m1524 <dbl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, N…
# $ newrel_m2534 <dbl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, N…
# $ newrel_m3544 <dbl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, N…
# $ newrel_m4554 <dbl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, N…
# $ newrel_m5564 <dbl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, N…
# $ newrel_m65   <dbl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, N…
# $ newrel_f014  <dbl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, N…
# $ newrel_f1524 <dbl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, N…
# $ newrel_f2534 <dbl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, N…
# $ newrel_f3544 <dbl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, N…
# $ newrel_f4554 <dbl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, N…
# $ newrel_f5564 <dbl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, N…
# $ newrel_f65   <dbl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, N…
# Rows: 266
# Columns: 69
# $ `Country Name`   <chr> "Aruba", "Africa Eastern and Southern", "Afghanistan"…
# $ `Country Code`   <chr> "ABW", "AFE", "AFG", "AFW", "AGO", "ALB", "AND", "ARB…
# $ `Indicator Name` <chr> "Population, total", "Population, total", "Population…
# $ `Indicator Code` <chr> "SP.POP.TOTL", "SP.POP.TOTL", "SP.POP.TOTL", "SP.POP.…
# $ `1960`           <dbl> 54922, 130072080, 9035043, 97630925, 5231654, 1608800…
# $ `1961`           <dbl> 55578, 133534923, 9214083, 99706674, 5301583, 1659800…
# $ `1962`           <dbl> 56320, 137171659, 9404406, 101854756, 5354310, 171131…
# $ `1963`           <dbl> 57002, 140945536, 9604487, 104089175, 5408320, 176262…
# $ `1964`           <dbl> 57619, 144904094, 9814318, 106388440, 5464187, 181413…
# $ `1965`           <dbl> 58190, 149033472, 10036008, 108772632, 5521981, 18647…
# $ `1966`           <dbl> 58694, 153281203, 10266395, 111246953, 5581386, 19145…
# $ `1967`           <dbl> 58990, 157704381, 10505959, 113795019, 5641807, 19655…
# $ `1968`           <dbl> 59069, 162329396, 10756922, 116444636, 5702699, 20222…
# $ `1969`           <dbl> 59052, 167088245, 11017409, 119203521, 5763685, 20816…
# $ `1970`           <dbl> 58950, 171984985, 11290128, 122086536, 5852788, 21354…
# $ `1971`           <dbl> 58781, 177022314, 11567667, 125072948, 5991102, 21878…
# $ `1972`           <dbl> 58047, 182126556, 11853696, 128176494, 6174262, 22431…
# $ `1973`           <dbl> 58299, 187524135, 12157999, 131449942, 6388528, 22967…
# $ `1974`           <dbl> 58349, 193186642, 12469127, 134911581, 6613367, 23501…
# $ `1975`           <dbl> 58295, 198914573, 12773954, 138569918, 6842947, 24048…
# $ `1976`           <dbl> 58368, 204802976, 13059851, 142337272, 7074664, 24585…
# $ `1977`           <dbl> 58580, 210680842, 13340756, 146258576, 7317829, 25135…
# $ `1978`           <dbl> 58776, 217074286, 13611441, 150402616, 7576734, 25662…
# $ `1979`           <dbl> 59191, 223974122, 13655567, 154721711, 7847207, 26178…
# $ `1980`           <dbl> 59909, 230792729, 13169311, 159166518, 8133872, 26719…
# $ `1981`           <dbl> 60563, 238043099, 11937581, 163762473, 8435607, 27260…
# $ `1982`           <dbl> 61276, 245822010, 10991378, 168585118, 8751648, 27842…
# $ `1983`           <dbl> 62228, 253644643, 10917982, 173255157, 9082983, 28439…
# $ `1984`           <dbl> 62901, 261458202, 11190221, 177880746, 9425917, 29044…
# $ `1985`           <dbl> 61728, 269450407, 11426852, 182811038, 9779120, 29647…
# $ `1986`           <dbl> 59931, 277621771, 11420074, 187889141, 10139450, 3022…
# $ `1987`           <dbl> 59159, 286067346, 11387818, 193104347, 10497858, 3083…
# $ `1988`           <dbl> 59331, 294498625, 11523298, 198485027, 10861291, 3142…
# $ `1989`           <dbl> 60443, 302939121, 11874088, 204062274, 11238562, 3227…
# $ `1990`           <dbl> 62753, 311748681, 12045660, 209566031, 11626360, 3286…
# $ `1991`           <dbl> 65896, 320442961, 12238879, 215178709, 12023529, 3266…
# $ `1992`           <dbl> 69005, 329082707, 13278974, 221191375, 12423712, 3247…
# $ `1993`           <dbl> 73685, 338324002, 14943172, 227246778, 12827135, 3227…
# $ `1994`           <dbl> 77595, 347441809, 16250794, 233360104, 13249764, 3207…
# $ `1995`           <dbl> 79805, 356580375, 17065836, 239801875, 13699778, 3187…
# $ `1996`           <dbl> 83021, 366138524, 17763266, 246415446, 14170973, 3168…
# $ `1997`           <dbl> 86301, 375646235, 18452091, 253207584, 14660413, 3148…
# $ `1998`           <dbl> 88451, 385505757, 19159996, 260297834, 15159370, 3128…
# $ `1999`           <dbl> 89659, 395750933, 19887785, 267506298, 15667235, 3108…
# $ `2000`           <dbl> 90588, 406156661, 20130327, 274968446, 16194869, 3089…
# $ `2001`           <dbl> 91439, 416807868, 20284307, 282780717, 16747208, 3060…
# $ `2002`           <dbl> 92074, 427820358, 21378117, 290841795, 17327699, 3051…
# $ `2003`           <dbl> 93128, 439173286, 22733049, 299142845, 17943712, 3039…
# $ `2004`           <dbl> 95138, 450928044, 23560654, 307725100, 18600423, 3026…
# $ `2005`           <dbl> 97635, 463076637, 24404567, 316588476, 19291161, 3011…
# $ `2006`           <dbl> 99405, 475606210, 25424094, 325663158, 20015279, 2992…
# $ `2007`           <dbl> 100150, 488580707, 25909852, 334984176, 20778561, 297…
# $ `2008`           <dbl> 100917, 502070763, 26482622, 344586109, 21578655, 294…
# $ `2009`           <dbl> 101604, 516003448, 27466101, 354343844, 22414773, 292…
# $ `2010`           <dbl> 101838, 530308387, 28284089, 364358270, 23294825, 291…
# $ `2011`           <dbl> 102591, 544737983, 29347708, 374790143, 24218352, 290…
# $ `2012`           <dbl> 104110, 559609961, 30560034, 385360349, 25177394, 290…
# $ `2013`           <dbl> 105675, 575202699, 31622704, 396030207, 26165620, 289…
# $ `2014`           <dbl> 106807, 590968990, 32792523, 406992047, 27160769, 288…
# $ `2015`           <dbl> 107906, 607123269, 33831764, 418127845, 28157798, 288…
# $ `2016`           <dbl> 108727, 623369401, 34700612, 429454743, 29183070, 287…
# $ `2017`           <dbl> 108735, 640058741, 35688935, 440882906, 30234839, 287…
# $ `2018`           <dbl> 108908, 657801085, 36743039, 452195915, 31297155, 286…
# $ `2019`           <dbl> 109203, 675950189, 37856121, 463365429, 32375632, 285…
# $ `2020`           <dbl> 108587, 694446100, 39068979, 474569351, 33451132, 283…
# $ `2021`           <dbl> 107700, 713090928, 40000412, 485920997, 34532429, 281…
# $ `2022`           <dbl> 107310, 731821393, 40578842, 497387180, 35635029, 277…
# $ `2023`           <dbl> 107359, 750503764, 41454761, 509398589, 36749906, 274…
# $ ...69            <lgl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, N…

# %% [markdown]
#    2.2. Import the data into tibbles named who and population.

# %%
as.tibble(who)
as.tibble(population)
# Out:
#      country     iso2 iso3 year new_sp_m014 new_sp_m1524 new_sp_m2534
# 1    Afghanistan AF   AFG  1980  NA          NA           NA
# 2    Afghanistan AF   AFG  1981  NA          NA           NA
# 3    Afghanistan AF   AFG  1982  NA          NA           NA
# 4    Afghanistan AF   AFG  1983  NA          NA           NA
# 5    Afghanistan AF   AFG  1984  NA          NA           NA
# 6    Afghanistan AF   AFG  1985  NA          NA           NA
# 7    Afghanistan AF   AFG  1986  NA          NA           NA
# 8    Afghanistan AF   AFG  1987  NA          NA           NA
# 9    Afghanistan AF   AFG  1988  NA          NA           NA
# 10   Afghanistan AF   AFG  1989  NA          NA           NA
# 11   Afghanistan AF   AFG  1990  NA          NA           NA
# 12   Afghanistan AF   AFG  1991  NA          NA           NA
# 13   Afghanistan AF   AFG  1992  NA          NA           NA
# 14   Afghanistan AF   AFG  1993  NA          NA           NA
# 15   Afghanistan AF   AFG  1994  NA          NA           NA
# 16   Afghanistan AF   AFG  1995  NA          NA           NA
# 17   Afghanistan AF   AFG  1996  NA          NA           NA
# 18   Afghanistan AF   AFG  1997   0          10            6
# 19   Afghanistan AF   AFG  1998  30         129          128
# 20   Afghanistan AF   AFG  1999   8          55           55
# 21   Afghanistan AF   AFG  2000  52         228          183
# 22   Afghanistan AF   AFG  2001 129         379          349
# 23   Afghanistan AF   AFG  2002  90         476          481
# 24   Afghanistan AF   AFG  2003 127         511          436
# 25   Afghanistan AF   AFG  2004 139         537          568
# 26   Afghanistan AF   AFG  2005 151         606          560
# 27   Afghanistan AF   AFG  2006 193         837          791
# 28   Afghanistan AF   AFG  2007 186         856          840
# 29   Afghanistan AF   AFG  2008 187         941          773
# 30   Afghanistan AF   AFG  2009 200         906          705
# ⋮    ⋮           ⋮    ⋮    ⋮    ⋮           ⋮            ⋮
# 7211 Zimbabwe    ZW   ZWE  1984  NA          NA            NA
# 7212 Zimbabwe    ZW   ZWE  1985  NA          NA            NA
# 7213 Zimbabwe    ZW   ZWE  1986  NA          NA            NA
# 7214 Zimbabwe    ZW   ZWE  1987  NA          NA            NA
# 7215 Zimbabwe    ZW   ZWE  1988  NA          NA            NA
# 7216 Zimbabwe    ZW   ZWE  1989  NA          NA            NA
# 7217 Zimbabwe    ZW   ZWE  1990  NA          NA            NA
# 7218 Zimbabwe    ZW   ZWE  1991  NA          NA            NA
# 7219 Zimbabwe    ZW   ZWE  1992  NA          NA            NA
# 7220 Zimbabwe    ZW   ZWE  1993  NA          NA            NA
# 7221 Zimbabwe    ZW   ZWE  1994  NA          NA            NA
# 7222 Zimbabwe    ZW   ZWE  1995  NA          NA            NA
# 7223 Zimbabwe    ZW   ZWE  1996  NA          NA            NA
# 7224 Zimbabwe    ZW   ZWE  1997  NA          NA            NA
# 7225 Zimbabwe    ZW   ZWE  1998  NA          NA            NA
# 7226 Zimbabwe    ZW   ZWE  1999  NA          NA            NA
# 7227 Zimbabwe    ZW   ZWE  2000  NA          NA            NA
# 7228 Zimbabwe    ZW   ZWE  2001  NA          NA            NA
# 7229 Zimbabwe    ZW   ZWE  2002 191         600          2548
# 7230 Zimbabwe    ZW   ZWE  2003 133         874          3048
# 7231 Zimbabwe    ZW   ZWE  2004 187         833          2908
# 7232 Zimbabwe    ZW   ZWE  2005 210         837          2264
# 7233 Zimbabwe    ZW   ZWE  2006 215         736          2391
# 7234 Zimbabwe    ZW   ZWE  2007 138         500          3693
# 7235 Zimbabwe    ZW   ZWE  2008 127         614             0
# 7236 Zimbabwe    ZW   ZWE  2009 125         578            NA
# 7237 Zimbabwe    ZW   ZWE  2010 150         710          2208
# 7238 Zimbabwe    ZW   ZWE  2011 152         784          2467
# 7239 Zimbabwe    ZW   ZWE  2012 120         783          2421
# 7240 Zimbabwe    ZW   ZWE  2013  NA          NA            NA
#      new_sp_m3544 new_sp_m4554 new_sp_m5564 ⋯ newrel_m4554 newrel_m5564
# 1     NA           NA           NA          ⋯ NA           NA
# 2     NA           NA           NA          ⋯ NA           NA
# 3     NA           NA           NA          ⋯ NA           NA
# 4     NA           NA           NA          ⋯ NA           NA
# 5     NA           NA           NA          ⋯ NA           NA
# 6     NA           NA           NA          ⋯ NA           NA
# 7     NA           NA           NA          ⋯ NA           NA
# 8     NA           NA           NA          ⋯ NA           NA
# 9     NA           NA           NA          ⋯ NA           NA
# 10    NA           NA           NA          ⋯ NA           NA
# 11    NA           NA           NA          ⋯ NA           NA
# 12    NA           NA           NA          ⋯ NA           NA
# 13    NA           NA           NA          ⋯ NA           NA
# 14    NA           NA           NA          ⋯ NA           NA
# 15    NA           NA           NA          ⋯ NA           NA
# 16    NA           NA           NA          ⋯ NA           NA
# 17    NA           NA           NA          ⋯ NA           NA
# 18     3            5            2          ⋯ NA           NA
# 19    90           89           64          ⋯ NA           NA
# 20    47           34           21          ⋯ NA           NA
# 21   149          129           94          ⋯ NA           NA
# 22   274          204          139          ⋯ NA           NA
# 23   368          246          241          ⋯ NA           NA
# 24   284          256          288          ⋯ NA           NA
# 25   360          358          386          ⋯ NA           NA
# 26   472          453          470          ⋯ NA           NA
# 27   574          572          572          ⋯ NA           NA
# 28   597          566          630          ⋯ NA           NA
# 29   545          570          630          ⋯ NA           NA
# 30   499          491          596          ⋯ NA           NA
# ⋮    ⋮            ⋮            ⋮            ⋱ ⋮            ⋮
# 7211   NA           NA          NA          ⋯   NA           NA
# 7212   NA           NA          NA          ⋯   NA           NA
# 7213   NA           NA          NA          ⋯   NA           NA
# 7214   NA           NA          NA          ⋯   NA           NA
# 7215   NA           NA          NA          ⋯   NA           NA
# 7216   NA           NA          NA          ⋯   NA           NA
# 7217   NA           NA          NA          ⋯   NA           NA
# 7218   NA           NA          NA          ⋯   NA           NA
# 7219   NA           NA          NA          ⋯   NA           NA
# 7220   NA           NA          NA          ⋯   NA           NA
# 7221   NA           NA          NA          ⋯   NA           NA
# 7222   NA           NA          NA          ⋯   NA           NA
# 7223   NA           NA          NA          ⋯   NA           NA
# 7224   NA           NA          NA          ⋯   NA           NA
# 7225   NA           NA          NA          ⋯   NA           NA
# 7226   NA           NA          NA          ⋯   NA           NA
# 7227   NA           NA          NA          ⋯   NA           NA
# 7228   NA           NA          NA          ⋯   NA           NA
# 7229 1662          744         315          ⋯   NA           NA
# 7230 2228          981         367          ⋯   NA           NA
# 7231 2298         1056         366          ⋯   NA           NA
# 7232 1855          762         295          ⋯   NA           NA
# 7233 1939          896         348          ⋯   NA           NA
# 7234    0          716         292          ⋯   NA           NA
# 7235 3316          704         263          ⋯   NA           NA
# 7236 3471          681         293          ⋯   NA           NA
# 7237 1682          761         350          ⋯   NA           NA
# 7238 2071          780         377          ⋯   NA           NA
# 7239 2086          796         360          ⋯   NA           NA
# 7240   NA           NA          NA          ⋯ 2349         1206
#      newrel_m65 newrel_f014 newrel_f1524 newrel_f2534 newrel_f3544 newrel_f4554
# 1    NA         NA          NA           NA           NA           NA
# 2    NA         NA          NA           NA           NA           NA
# 3    NA         NA          NA           NA           NA           NA
# 4    NA         NA          NA           NA           NA           NA
# 5    NA         NA          NA           NA           NA           NA
# 6    NA         NA          NA           NA           NA           NA
# 7    NA         NA          NA           NA           NA           NA
# 8    NA         NA          NA           NA           NA           NA
# 9    NA         NA          NA           NA           NA           NA
# 10   NA         NA          NA           NA           NA           NA
# 11   NA         NA          NA           NA           NA           NA
# 12   NA         NA          NA           NA           NA           NA
# 13   NA         NA          NA           NA           NA           NA
# 14   NA         NA          NA           NA           NA           NA
# 15   NA         NA          NA           NA           NA           NA
# 16   NA         NA          NA           NA           NA           NA
# 17   NA         NA          NA           NA           NA           NA
# 18   NA         NA          NA           NA           NA           NA
# 19   NA         NA          NA           NA           NA           NA
# 20   NA         NA          NA           NA           NA           NA
# 21   NA         NA          NA           NA           NA           NA
# 22   NA         NA          NA           NA           NA           NA
# 23   NA         NA          NA           NA           NA           NA
# 7238  NA           NA
# 7239  NA           NA
# 7240 811          725
#     Country Name                                         Country Code
# 1   Aruba                                                ABW
# 2   Africa Eastern and Southern                          AFE
# 3   Afghanistan                                          AFG
# 4   Africa Western and Central                           AFW
# 5   Angola                                               AGO
# 6   Albania                                              ALB
# 7   Andorra                                              AND
# 8   Arab World                                           ARB
# 9   United Arab Emirates                                 ARE
# 10  Argentina                                            ARG
# 11  Armenia                                              ARM
# 12  American Samoa                                       ASM
# 13  Antigua and Barbuda                                  ATG
# 14  Australia                                            AUS
# 15  Austria                                              AUT
# 16  Azerbaijan                                           AZE
# 17  Burundi                                              BDI
# 18  Belgium                                              BEL
# 19  Benin                                                BEN
# 20  Burkina Faso                                         BFA
# 21  Bangladesh                                           BGD
# 22  Bulgaria                                             BGR
# 23  Bahrain                                              BHR
# 24  Bahamas, The                                         BHS
# 25  Bosnia and Herzegovina                               BIH
# 26  Belarus                                              BLR
# 27  Belize                                               BLZ
# 28  Bermuda                                              BMU
# 29  Bolivia                                              BOL
# 30  Brazil                                               BRA
# ⋮   ⋮                                                    ⋮
# 237 Latin America & the Caribbean (IDA & IBRD countries) TLA
# 238 Timor-Leste                                          TLS
# 239 Middle East & North Africa (IDA & IBRD countries)    TMN
# 240 Tonga                                                TON
# 241 South Asia (IDA & IBRD)                              TSA
# 242 Sub-Saharan Africa (IDA & IBRD countries)            TSS
# 243 Trinidad and Tobago                                  TTO
# 244 Tunisia                                              TUN
# 245 Turkiye                                              TUR
# 246 Tuvalu                                               TUV
# 247 Tanzania                                             TZA
# 248 Uganda                                               UGA
# 249 Ukraine                                              UKR
# 250 Upper middle income                                  UMC
# 251 Uruguay                                              URY
# 252 United States                                        USA
# 253 Uzbekistan                                           UZB
# 254 St. Vincent and the Grenadines                       VCT
# 255 Venezuela, RB                                        VEN
# 256 British Virgin Islands                               VGB
# 257 Virgin Islands (U.S.)                                VIR
# 258 Viet Nam                                             VNM
# 259 Vanuatu                                              VUT
# 260 World                                                WLD
# 261 Samoa                                                WSM
# 262 Kosovo                                               XKX
# 263 Yemen, Rep.                                          YEM
# 264 South Africa                                         ZAF
# 265 Zambia                                               ZMB
# 266 Zimbabwe                                             ZWE
#     Indicator Name    Indicator Code 1960       1961       1962
# 1   Population, total SP.POP.TOTL        54922      55578      56320
# 2   Population, total SP.POP.TOTL    130072080  133534923  137171659
# 3   Population, total SP.POP.TOTL      9035043    9214083    9404406
# 4   Population, total SP.POP.TOTL     97630925   99706674  101854756
# 5   Population, total SP.POP.TOTL      5231654    5301583    5354310
# 6   Population, total SP.POP.TOTL      1608800    1659800    1711319
# 7   Population, total SP.POP.TOTL         9510      10283      11086
# 8   Population, total SP.POP.TOTL     91540853   93931683   96428599
# 9   Population, total SP.POP.TOTL       131334     137989     144946
# 10  Population, total SP.POP.TOTL     20386045   20726276   21072538
# 11  Population, total SP.POP.TOTL      1863705    1927484    1991689
# 12  Population, total SP.POP.TOTL        20133      20666      21298
# 13  Population, total SP.POP.TOTL        55603      56540      57336
# 14  Population, total SP.POP.TOTL     10276477   10483000   10742000
# 15  Population, total SP.POP.TOTL      7047539    7086299    7129864
# 16  Population, total SP.POP.TOTL      3894500    4045750    4168150
# 17  Population, total SP.POP.TOTL      2764258    2835119    2907943
# 18  Population, total SP.POP.TOTL      9153489    9183948    9220578
# 19  Population, total SP.POP.TOTL      2517286    2559223    2604659
# 20  Population, total SP.POP.TOTL      4778621    4848224    4919672
# 21  Population, total SP.POP.TOTL     51828660   53310348   54881146
# 22  Population, total SP.POP.TOTL      7867374    7943118    8012946
# 23  Population, total SP.POP.TOTL       165477     172346     179349
# 24  Population, total SP.POP.TOTL       116317     122197     128493
# 25  Population, total SP.POP.TOTL      3281381    3348035    3407532
# 26  Population, total SP.POP.TOTL      8198000    8271216    8351928
# 27  Population, total SP.POP.TOTL        91318      93632      96042
# 28  Population, total SP.POP.TOTL        42208      43123      44239
# 29  Population, total SP.POP.TOTL      3702323    3778731    3857493
# 30  Population, total SP.POP.TOTL     72388126   74605447   76865323
# ⋮   ⋮                 ⋮              ⋮          ⋮          ⋮
# 237 Population, total SP.POP.TOTL     208671107  214582669  220668336
# 238 Population, total SP.POP.TOTL        468118     475291     482774
# 239 Population, total SP.POP.TOTL      97138700   99660885  102288730
# 240 Population, total SP.POP.TOTL         66170      68037      69940
# 241 Population, total SP.POP.TOTL     562663671  576552257  590723078
# 242 Population, total SP.POP.TOTL     227703005  233241597  239026415
# 243 Population, total SP.POP.TOTL        844943     863144     880194
# 244 Population, total SP.POP.TOTL       4267288    4316278    4369136
# 245 Population, total SP.POP.TOTL      28329898   29119238   29916147
# 246 Population, total SP.POP.TOTL          5598       5648       5699
# 247 Population, total SP.POP.TOTL       9901419   10187886   10487756
# 248 Population, total SP.POP.TOTL       7640973    7862217    8092231
# 249 Population, total SP.POP.TOTL      42824093   43399766   43943674
# 250 Population, total SP.POP.TOTL    1151246171 1157236371 1175758905
# 251 Population, total SP.POP.TOTL       2529957    2562044    2593298
# 252 Population, total SP.POP.TOTL     180671000  183691000  186538000
# 253 Population, total SP.POP.TOTL       8209109    8517711    8854368
# 254 Population, total SP.POP.TOTL         84388      85870      87236
# 255 Population, total SP.POP.TOTL       8160090    8455915    8756870
# 256 Population, total SP.POP.TOTL          7950       8034       8070
# 257 Population, total SP.POP.TOTL         32500      34300      35000
# 258 Population, total SP.POP.TOTL      32531933   33409059   34288560
# 259 Population, total SP.POP.TOTL         64431      66264      68174
# 260 Population, total SP.POP.TOTL    3021529236 3062769479 3117373096
# 261 Population, total SP.POP.TOTL        112490     115496     118597
# 262 Population, total SP.POP.TOTL        984846    1011421    1036950
# 263 Population, total SP.POP.TOTL       5532301    5655232    5782221
# 264 Population, total SP.POP.TOTL      16440172   16908035   17418522
# 265 Population, total SP.POP.TOTL       3153729    3254086    3358099
# 266 Population, total SP.POP.TOTL       3809389    3930401    4055959
#     1963       1964       1965       ⋯ 2015       2016       2017
⋮          ⋮          ⋮          ⋮          ⋮          ⋮
# 237  620274430  625467307  630051021  633862610  637837815  642397939 NA
# 238    1275959    1300945    1326053    1350139    1369295    1384286 NA
# 239  400206414  407148671  413658033  420057840  427185536  434952414 NA
# 240     105567     105669     105704     105490     105042     104597 NA
# 241 1852836645 1874070006 1895144142 1914263569 1932289074 1951539835 NA
# 242 1109997000 1139315618 1169015451 1199011925 1229208573 1259902353 NA
# 243    1359193    1363985    1366725    1367558    1365805    1367510 NA
# 244   11765514   11875081   11974057   12048622   12119334   12200431 NA
# 245   81407204   82579440   83384680   84147318   84979913   85325965 NA
# 246      10751      10581      10399      10194       9992       9816 NA
# 247   57437145   59174891   60972798   62830412   64711821   66617606 NA
# 248   41565831   42999637   44457152   45910930   47312719   48656601 NA
# 249   45208907   44957458   44680014   44298640   41048766   37732836 NA
# 250 2758643432 2777172392 2792212417 2803460465 2810662434 2816864459 NA
# 251    3394534    3397206    3398968    3396695    3390913    3388081 NA
# 252  326838199  328329953  331526933  332048977  333271411  334914895 NA
# 253   32373490   32964701   33586372   34243696   34938955   35652307 NA
# 254     104926     104167     103526     102841     102046     101323 NA
# 255   29807592   28938098   28444077   28237826   28213017   28300854 NA
# 256      34657      36395      37135      37809      38319      38985 NA
# 257     107001     106669     106290     105870     105413     104917 NA
# 258   96237319   97173776   98079191   98935098   99680655  100352192 NA
# 259     285259     291985     298858     305868     313046     320409 NA
# 260 7696494848 7776892015 7856138790 7921184346 7989981520 8061876001 NA
# 261     207582     209780     211944     213779     215261     216663 NA
# 262    1797086    1788891    1790152    1786080    1768096    1756366 NA
# 263   34085182   35111408   36134863   37140230   38222876   39390799 NA
# 264   58613001   59587885   60562381   61502603   62378410   63212384 NA
# 265   17973569   18513839   19059395   19603607   20152938   20723965 NA
# 266   15034452   15271368   15526888   15797210   16069056   16340822 NA

# %% [markdown]
#    2.3. Determine the number of rows and columns in each tibble.

# %%
cat("Who\nNumber of Rows: ", nrow(who))
cat("\nNumber of Columns: ", ncol(who))

cat("\n\nPopulation\nNumber of Rows: ", nrow(population))
cat("\nNumber of Columns: ", ncol(population))
# Out:
# Who
# Number of Rows:  7240
# Number of Columns:  60
#
# Population
# Number of Rows:  266
# Number of Columns:  69

# %% [markdown]
#    2.4. Check the summary of variable types for population.csv. Fix any anomalies and store the corrected data in population2.

# %%
summary(population)
# Out:
#  Country Name       Country Code       Indicator Name     Indicator Code
#  Length:266         Length:266         Length:266         Length:266
#  Class :character   Class :character   Class :character   Class :character
#  Mode  :character   Mode  :character   Mode  :character   Mode  :character
#
#
#
#
#       1960                1961                1962
#  Min.   :2.715e+03   Min.   :2.970e+03   Min.   :3.264e+03
#  1st Qu.:5.152e+05   1st Qu.:5.255e+05   1st Qu.:5.363e+05
#  Median :3.660e+06   Median :3.747e+06   Median :3.832e+06
#  Mean   :1.154e+08   Mean   :1.171e+08   Mean   :1.192e+08
#  3rd Qu.:2.686e+07   3rd Qu.:2.761e+07   3rd Qu.:2.837e+07
#  Max.   :3.022e+09   Max.   :3.063e+09   Max.   :3.117e+09
#  NA's   :2           NA's   :2           NA's   :2
#       1963                1964                1965
#  Min.   :3.584e+03   Min.   :3.922e+03   Min.   :4.282e+03
#  1st Qu.:5.476e+05   1st Qu.:5.594e+05   1st Qu.:5.676e+05
#  Median :3.920e+06   Median :4.010e+06   Median :4.103e+06
#  Mean   :1.219e+08   Mean   :1.246e+08   Mean   :1.273e+08
#  3rd Qu.:2.915e+07   3rd Qu.:2.995e+07   3rd Qu.:3.076e+07
#  Max.   :3.184e+09   Max.   :3.251e+09   Max.   :3.319e+09
#  NA's   :2           NA's   :2           NA's   :2
#       
+09
#  NA's   :2           NA's   :2           NA's   :2
#       1984                1985                1986
#  Min.   :7.902e+03   Min.   :8.046e+03   Min.   :8.217e+03
#  1st Qu.:8.710e+05   1st Qu.:8.880e+05   1st Qu.:9.076e+05
#  Median :6.285e+06   Median :6.423e+06   Median :6.542e+06
#  Mean   :1.869e+08   Mean   :1.905e+08   Mean   :1.942e+08
#  3rd Qu.:4.225e+07   3rd Qu.:4.300e+07   3rd Qu.:4.370e+07
#  Max.   :4.766e+09   Max.   :4.851e+09   Max.   :4.938e+09
#  NA's   :2           NA's   :2           NA's   :2
#       1987                1988                1989
#  Min.   :8.371e+03   Min.   :8.518e+03   Min.   :8.662e+03
#  1st Qu.:9.300e+05   1st Qu.:9.631e+05   1st Qu.:9.980e+05
#  Median :6.702e+06   Median :6.846e+06   Median :7.038e+06
#  Mean   :1.979e+08   Mean   :2.017e+08   Mean   :2.055e+08
#  3rd Qu.:4.472e+07   3rd Qu.:4.604e+07   3rd Qu.:4.739e+07
#  Max.   :5.027e+09   Max.   :5.117e+09   Max.   :5.208e+09
#  NA's   :2           NA's   :2           NA's   :2
#       1990                1991                1992
#  Min.   :8.798e+03   Min.   :8.928e+03   Min.   :9.038e+03
#  1st Qu.:1.055e+06   1st Qu.:1.070e+06   1st Qu.:1.084e+06
#  Median :7.130e+06   Median :7.271e+06   Median :7.382e+06
#  Mean   :2.085e+08   Mean   :2.123e+08   Mean   :2.160e+08
#  3rd Qu.:4.761e+07   3rd Qu.:4.972e+07   3rd Qu.:5.185e+07
#  Max.   :5.299e+09   Max.   :5.388e+09   Max.   :5.477e+09
#  NA's   :1           NA's   :1           NA's   :1
#       1993                1994                1995
#  Min.   :9.126e+03   Min.   :9.207e+03   Min.   :9.280e+03
#  1st Qu.:1.097e+06   1st Qu.:1.113e+06   1st Qu.:1.123e+06
#  Median :7.495e+06   Median :7.420e+06   Median :7.563e+06
#  Mean   :2.197e+08   Mean   :2.233e+08   Mean   :2.269e+08
#  3rd Qu.:5.235e+07   3rd Qu.:5.208e+07   3rd Qu.:5.167e+07
#  Max.   :5.565e+09   Max.   :5.651e+09   Max.   :5.737e+09
#  NA's   :1           NA's   :1           NA's   :1
#       1996                1997                1998
#  Min.   :9.342e+03   Min.   :9.400e+03   Min.   :9.451e+03
#  1st Qu.:1.152e+06   1st Qu.:1.181e+06   1st Qu.:1.212e+06
#  Median :7.708e+06   Median :7.838e+06   Median :8.002e+06
#  Mean   :2.306e+08   Mean   :2.342e+08   Mean   :2.378e+08
#  3rd Qu.:5.123e+07   3rd Qu.:5.079e+07   3rd Qu.:5.038e+07
#  Max.   :5.823e+09   Max.   :5.908e+09   Max.   :5.994e+09
#  NA's   :1           NA's   :1           NA's   :1
#       1999                2000                2001
#  Min.   :9.496e+03   Min.   :9.544e+03   Min.   :9.586e+03
#  1st Qu.:1.243e+06   1st Qu.:1.276e+06   1st Qu.:1.310e+06
#  Median :8.151e+06   Median :8.214e+06   Median :8.287e+06
#  Mean   :2.414e+08   Mean   :2.450e+08   Mean   :2.485e+08
#  3rd Qu.:4.998e+07   3rd Qu.:5.051e+07   3rd Qu.:5.213e+07
#  Max.   :6.078e+09   Max.   :6.162e+09   Max.   :6.245e+09
#  NA's   :1           NA's   :1           NA's   :1
#       2002                2003                2004
#  Min.   :9.623e+03   Min.   :9.695e+03   Min.   :9.816e+03
#  1st Qu.:1.332e+06   1st Qu.:1.339e+06   1st Qu.:1.350e+06
#  Median :8.400e+06   Median :8.587e+06   Median :8.817e+06
#  Mean   :2.521e+08   Mean   :2.556e+08   Mean   :2.592e+08
#  3rd Qu.:5.375e+07   3rd Qu.:5.534e+07   3rd Qu.:5.700e+07
#  Max.   :6.328e+09   Max.   :6.410e+09   Max.   :6.493e+09
#  NA's   :1           NA's   :1           NA's   :1
#       2005                2006                2007
#  Min.   :9.940e+03   Min.   :1.003e+04   Min.   :1.002e+04
#  1st Qu.:1.355e+06   1st Qu.:1.347e+06   1st Qu.:1.341e+06
#  Median :9.030e+06   Median :9.081e+06   Median :9.148e+06
#  Mean   :2.628e+08   Mean   :2.664e+08   Mean   :2.700e+08
#  3rd Qu.:5.797e+07   3rd Qu.:5.814e+07   3rd Qu.:5.844e+07
#  Max.   :6.576e+09   Max.   :6.660e+09   Max.   :6.744e+09
#  NA's   :1           NA's   :1           NA's   :1
#       2008                2009                2010
#  Min.   :1.001e+04   Min.   :1.002e+04   Min.   :1.004e+04
#  1st Qu.:1.427e+06   1st Qu.:1.526e+06   1st Qu.:1.566e+06
#  Median :9.228e+06   Median :9.505e+06   Median :9.746e+06
#  Mean   :2.737e+08   Mean   :2.774e+08   Mean   :2.812e+08
#  3rd Qu.:5.883e+07   3rd Qu.:5.910e+07   3rd Qu.:5.928e+07
#  Max.   :6.830e+09   Max.   :6.916e+09   Max.   :7.001e+09
#  NA's   :1           NA's   :1           NA's   :1
#       2011                2012                2013
#  Min.   :1.010e+04   Min.   :1.027e+04   Min.   :1.052e+04
#  1st Qu.:1.608e+06   1st Qu.:1.651e+06   1st Qu.:1.696e+06
#  Median :9.915e+06   Median :1.007e+07   Median :1.019e+07
#  Mean   :2.849e+08   Mean   :2.888e+08   Mean   :2.927e+08
#  3rd Qu.:5.938e+07   3rd Qu.:5.954e+07   3rd Qu.:6.023e+07
#  Max.   :7.086e+09   Max.   :7.176e+09   Max.   :7.265e+09
#  NA's   :1           NA's   :1           NA's   :1
#       2014                2015                2016
#  Min.   :1.074e+04   Min.   :1.095e+04   Min.   :1.093e+04
#  1st Qu.:1.741e+06   1st Qu.:1.786e+06   1st Qu.:1.778e+06
#  Median :1.032e+07   Median :1.036e+07   Median :1.033e+07
#  Mean   :2.966e+08   Mean   :3.005e+08   Mean   :3.043e+08
#  3rd Qu.:6.079e+07   3rd Qu.:6.073e+07   3rd Qu.:6.063e+07
#  Max.   :7.354e+09   Max.   :7.441e+09   Max.   :7.529e+09
#  NA's   :1           NA's   :1           NA's   :1
#       2017                2018                2019
#  Min.   :1.087e+04   Min.   :1.075e+04   Min.   :1.058e+04
#  1st Qu.:1.791e+06   1st Qu.:1.797e+06   1st Qu.:1.789e+06
#  Median :1.026e+07   Median :1.028e+07   Median :1.042e+07
#  Mean   :3.082e+08   Mean   :3.119e+08   Mean   :3.156e+08
#  3rd Qu.:6.054e+07   3rd Qu.:6.042e+07   3rd Qu.:5.973e+07
#  Max.   :7.614e+09   Max.   :7.696e+09   Max.   :7.777e+09
#  NA's   :1           NA's   :1           NA's   :1
#       2020                2021                2022
#  Min.   :1.040e+04   Min.   :1.019e+04   Min.   :9.992e+03
#  1st Qu.:1.790e+06   1st Qu.:1.786e+06   1st Qu.:1.804e+06
#  Median :1.070e+07   Median :1.051e+07   Median :1.049e+07
#  Mean   :3.192e+08   Mean   :3.224e+08   Mean   :3.255e+08
#  3rd Qu.:6.097e+07   3rd Qu.:6.283e+07   3rd Qu.:6.471e+07
#  Max.   :7.856e+09   Max.   :7.921e+09   Max.   :7.990e+09
#  NA's   :1           NA's   :1           NA's   :1
#       2023            ...69
#  Min.   :9.816e+03   Mode:logical
#  1st Qu.:1.828e+06   NA's:266
#  Median :1.064e+07
#  Mean   :3.288e+08
#  3rd Qu.:6.662e+07
#  Max.   :8.062e+09
#  NA's   :1

# %%
# 2.4 Summary and cleaning population
glimpse(population)
# Assuming population values were imported as characters due to formatting
population2 <- population %>%
  mutate(across(-"Country Name", as.numeric))
# Out:
# Rows: 266
# Columns: 69
# $ `Country Name`   <chr> "Aruba", "Africa Eastern and Southern", "Afghanistan"…
# $ `Country Code`   <chr> "ABW", "AFE", "AFG", "AFW", "AGO", "ALB", "AND", "ARB…
# $ `Indicator Name` <chr> "Population, total", "Population, total", "Population…
# $ `Indicator Code` <chr> "SP.POP.TOTL", "SP.POP.TOTL", "SP.POP.TOTL", "SP.POP.…
# $ `1960`           <dbl> 54922, 130072080, 9035043, 97630925, 5231654, 1608800…
# $ `1961`           <dbl> 55578, 133534923, 9214083, 99706674, 5301583, 1659800…
# $ `1962`           <dbl> 56320, 137171659, 9404406, 101854756, 5354310, 171131…
# $ `1963`           <dbl> 57002, 140945536, 9604487, 104089175, 5408320, 176262…
# $ `1964`           <dbl> 57619, 144904094, 9814318, 106388440, 5464187, 181413…
# $ `1965`           <dbl> 58190, 149033472, 10036008, 108772632, 5521981, 18647…
# $ `1966`           <dbl> 58694, 153281203, 10266395, 111246953, 5581386, 19145…
# $ `1967`           <dbl> 58990, 157704381, 10505959, 113795019, 5641807, 19655…
# $ `1968`           <dbl> 59069, 162329396, 10756922, 116444636, 5702699, 20222…
# $ `1969`           <dbl> 59052, 167088245, 11017409, 119203521, 5763685, 20816…
# $ `1970`           <dbl> 58950, 171984985, 11290128, 122086536, 5852788, 21354…
# $ `1971`           <dbl> 58781, 177022314, 11567667, 125072948, 5991102, 21878…
# $ `1972`           <dbl> 58047, 182126556, 11853696, 128176494, 6174262, 22431…
# $ `1973`           <dbl> 58299, 187524135, 12157999, 131449942, 6388528, 22967…
# $ `1974`           <dbl> 58349, 193186642, 12469127, 134911581, 6613367, 23501…
# $ `1975`           <dbl> 58295, 198914573, 12773954, 138569918, 6842947, 24048…
# $ `1976`           <dbl> 58368, 204802976, 13059851, 142337272, 7074664, 24585…
# $ `1977`           <dbl> 58580, 210680842, 13340756, 146258576, 7317829, 25135…
# $ `1978`           <dbl> 58776, 217074286, 13611441, 150402616, 7576734, 25662…
# $ `1979`           <dbl> 59191, 223974122, 13655567, 154721711, 7847207, 26178…
# $ `1980`           <dbl> 59909, 230792729, 13169311, 159166518, 8133872, 26719…
# $ `1981`           <dbl> 60563, 238043099, 11937581, 163762473, 8435607, 27260…
# $ `1982`           <dbl> 61276, 245822010, 10991378, 168585118, 8751648, 27842…
# $ `1983`           <dbl> 62228, 253644643, 10917982, 173255157, 9082983, 28439…
# $ `1984`           <dbl> 62901, 261458202, 11190221, 177880746, 9425917, 29044…
# $ `1985`           <dbl> 61728, 269450407, 11426852, 182811038, 9779120, 29647…
# $ `1986`           <dbl> 59931, 277621771, 11420074, 187889141, 10139450, 3022…
# $ `1987`           <dbl> 59159, 286067346, 11387818, 193104347, 10497858, 3083…
# $ `1988`           <dbl> 59331, 294498625, 11523298, 198485027, 10861291, 3142…
# $ `1989`           <dbl> 60443, 302939121, 11874088, 204062274, 11238562, 3227…
# $ `1990`           <dbl> 62753, 311748681, 12045660, 209566031, 11626360, 3286…
# $ `1991`           <dbl> 65896, 320442961, 12238879, 215178709, 12023529, 3266…
# $ `1992`           <dbl> 69005, 329082707, 13278974, 221191375, 12423712, 3247…
# $ `1993`           <dbl> 73685, 338324002, 14943172, 227246778, 12827135, 3227…
# $ `1994`           <dbl> 77595, 347441809, 16250794, 233360104, 13249764, 3207…
# $ `1995`           <dbl> 79805, 356580375, 17065836, 239801875, 13699778, 3187…
# $ `1996`           <dbl> 83021, 366138524, 17763266, 246415446, 14170973, 3168…
# $ `1997`           <dbl> 86301, 375646235, 18452091, 253207584, 14660413, 3148…
# $ `1998`           <dbl> 88451, 385505757, 19159996, 260297834, 15159370, 3128…
# $ `1999`           <dbl> 89659, 395750933, 19887785, 267506298, 15667235, 3108…
# $ `2000`           <dbl> 90588, 406156661, 20130327, 274968446, 16194869, 3089…
# $ `2001`           <dbl> 91439, 416807868, 20284307, 282780717, 16747208, 3060…
# $ `2002`           <dbl> 92074, 427820358, 21378117, 290841795, 17327699, 3051…
# $ `2003`           <dbl> 93128, 439173286, 22733049, 299142845, 17943712, 3039…
# $ `2004`           <dbl> 95138, 450928044, 23560654, 307725100, 18600423, 3026…
# $ `2005`           <dbl> 97635, 463076637, 24404567, 316588476, 19291161, 3011…
# $ `2006`           <dbl> 99405, 475606210, 25424094, 325663158, 20015279, 2992…
# $ `2007`           <dbl> 100150, 488580707, 25909852, 334984176, 20778561, 297…
# $ `2008`           <dbl> 100917, 502070763, 26482622, 344586109, 21578655, 294…
# $ `2009`           <dbl> 101604, 516003448, 27466101, 354343844, 22414773, 292…
# $ `2010`           <dbl> 101838, 530308387, 28284089, 364358270, 23294825, 291…
# $ `2011`           <dbl> 102591, 544737983, 29347708, 374790143, 24218352, 290…
# $ `2012`           <dbl> 104110, 559609961, 30560034, 385360349, 25177394, 290…
# $ `2013`           <dbl> 105675, 575202699, 31622704, 396030207, 26165620, 289…
# $ `2014`           <dbl> 106807, 590968990, 32792523, 406992047, 27160769, 288…
# $ `2015`           <dbl> 107906, 607123269, 33831764, 418127845, 28157798, 288…
# $ `2016`           <dbl> 108727, 623369401, 34700612, 429454743, 29183070, 287…
# $ `2017`           <dbl> 108735, 640058741, 35688935, 440882906, 30234839, 287…
# $ `2018`           <dbl> 108908, 657801085, 36743039, 452195915, 31297155, 286…
# $ `2019`           <dbl> 109203, 675950189, 37856121, 463365429, 32375632, 285…
# $ `2020`           <dbl> 108587, 694446100, 39068979, 474569351, 33451132, 283…
# $ `2021`           <dbl> 107700, 713090928, 40000412, 485920997, 34532429, 281…
# $ `2022`           <dbl> 107310, 731821393, 40578842, 497387180, 35635029, 277…
# $ `2023`           <dbl> 107359, 750503764, 41454761, 509398589, 36749906, 274…
# $ ...69            <lgl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, N…
# Warning message:
# “There were 3 warnings in `mutate()`.
# The first warning was:
# ℹ In argument: `across(-"Country Name", as.numeric)`.
# Caused by warning:
# ! NAs introduced by coercion
# ℹ Run `dplyr::last_dplyr_warnings()` to see the 2 remaining warnings.”

# %% [markdown]
# **3. Tidy Data**
#
# 3.1.1 Identify the variables in the dataset.
#
# - country: Name of the Country
#
# - iso2 & iso3: Country code.
#
# - year: Year of the data was recorded.
#
# - Other columns are also variables

# %% [markdown]
#   3.1.2 Perform a pivot operation to make the data tidy, storing the result in who2.
#
#   3.1.3 Separate values like new_ep_f014 into components (e.g., new, ep, f014). Remove the column containing new, and store the result in who3.
#
#   3.1.4 Further separate values like f014 into f and 014, storing the result in who_tidy.

# %%
# Pivot operation
who2 <- who %>%
  pivot_longer(
    cols = new_sp_m014:newrel_f65,
    names_to = "key",
    values_to = "cases",
    values_drop_na = TRUE
  )

# Separate and remove 'new'
# Fix the 'newrel' inconsistency first
who3 <- who2 %>%
  mutate(key = str_replace(key, "newrel", "new_rel")) %>%
  separate(key, c("new", "type", "sexage"), sep = "_") %>%
  select(-new, -iso2, -iso3)

# 3.1.4 Separate sex and age
who_tidy <- who3 %>%
  separate(sexage, c("sex", "age"), sep = 1)

# %% [markdown]
# **3.2 Population Dataset**
#
#   3.2.1 Identify the variables in this dataset.
#   - country: Country name
#   - year: Year of the data recorded
#   - population: Population of  the Country
#
#   3.2.2 Perform a pivot operation to tidy the data, storing the result in population3.
#
#   3.2.3 Cast the population variable to an appropriate data type, storing the result in population_tidy.

# %%
# Section 3.2: Clean the Population data
# 3.2.1 & 3.2.2 Read and Pivot
population3 <- population %>%
  pivot_longer(
    cols = -c("Country Name", "Country Code", "Indicator Name", "Indicator Code"),
    names_to = "year",
    values_to = "population"
  )

head(population3)
# Out:
#   Country Name Country Code Indicator Name    Indicator Code year population
# 1 Aruba        ABW          Population, total SP.POP.TOTL    1960 54922
# 2 Aruba        ABW          Population, total SP.POP.TOTL    1961 55578
# 3 Aruba        ABW          Population, total SP.POP.TOTL    1962 56320
# 4 Aruba        ABW          Population, total SP.POP.TOTL    1963 57002
# 5 Aruba        ABW          Population, total SP.POP.TOTL    1964 57619
# 6 Aruba        ABW          Population, total SP.POP.TOTL    1965 58190

# %%
# Fix data types and filter out the extra column
population_tidy <- population3 %>%
  # 1. Filter out rows that don't have a proper year (like ...69 or Unnamed)
  # str_detect looks for rows that start with "..."
  filter(!str_detect(year, "\\.\\.\\.")) %>%

  # 2. Now perform the conversion
  mutate(
    year = as.integer(readr::parse_number(year)),
    population = as.numeric(population)
  ) %>%
  rename(country="Country Name")

# Check the summary again - the warning should be gone
summary(population_tidy)
# Out:
#    country          Country Code       Indicator Name     Indicator Code
#  Length:17024       Length:17024       Length:17024       Length:17024
#  Class :character   Class :character   Class :character   Class :character
#  Mode  :character   Mode  :character   Mode  :character   Mode  :character
#
#
#
#
#       year        population
#  Min.   :1960   Min.   :2.715e+03
#  1st Qu.:1976   1st Qu.:1.010e+06
#  Median :1992   Median :6.749e+06
#  Mean   :1992   Mean   :2.166e+08
#  3rd Qu.:2007   3rd Qu.:4.679e+07
#  Max.   :2023   Max.   :8.062e+09
#                 NA's   :94

# %%
setdiff(unique(who_tidy$country), unique(population_tidy$country))
# Out:
#  [1] "Anguilla"
#  [2] "Bahamas"
#  [3] "Bolivia (Plurinational State of)"
#  [4] "Bonaire, Saint Eustatius and Saba"
#  [5] "China, Hong Kong SAR"
#  [6] "China, Macao SAR"
#  [7] "Congo"
#  [8] "Cook Islands"
#  [9] "Czech Republic"
# [10] "Democratic People's Republic of Korea"
# [11] "Democratic Republic of the Congo"
# [12] "Egypt"
# [13] "Gambia"
# [14] "Iran (Islamic Republic of)"
# [15] "Kyrgyzstan"
# [16] "Lao People's Democratic Republic"
# [17] "Micronesia (Federated States of)"
# [18] "Montserrat"
# [19] "Netherlands Antilles"
# [20] "Niue"
# [21] "Republic of Korea"
# [22] "Republic of Moldova"
# [23] "Saint Kitts and Nevis"
# [24] "Saint Lucia"
# [25] "Saint Vincent and the Grenadines"
# [26] "Serbia & Montenegro"
# [27] "Slovakia"
# [28] "Swaziland"
# [29] "The Former Yugoslav Republic of Macedonia"
# [30] "Tokelau"
# [31] "Turkey"
# [32] "United Kingdom of Great Britain and Northern Ireland"
# [33] "United Republic of Tanzania"
# [34] "United States of America"
# [35] "US Virgin Islands"
# [36] "Venezuela (Bolivarian Republic of)"
# [37] "Wallis and Futuna Islands"
# [38] "West Bank and Gaza Strip"
# [39] "Yemen"

# %%
who_tidy <- who_tidy %>%
  mutate(country = recode(country,
    # WHO Name = Population Dataset Name
    "Bahamas" = "Bahamas, The",
    "Bolivia (Plurinational State of)" = "Bolivia",
    "Congo" = "Congo, Rep.",
    "Democratic Republic of the Congo" = "Congo, Dem. Rep.",
    "Democratic People's Republic of Korea" = "Korea, Dem. People's Rep.",
    "Egypt" = "Egypt, Arab Rep.",
    "Gambia" = "Gambia, The",
    "Iran (Islamic Republic of)" = "Iran, Islamic Rep.",
    "Kyrgyzstan" = "Kyrgyz Republic",
    "Lao People's Democratic Republic" = "Lao PDR",
    "Micronesia (Federated States of)" = "Micronesia, Fed. Sts.",
    "Republic of Korea" = "Korea, Rep.",
    "Republic of Moldova" = "Moldova",
    "Slovakia" = "Slovak Republic",
    "Swaziland" = "Eswatini",
    "Turkey" = "Turkiye",
    "United Kingdom of Great Britain and Northern Ireland" = "United Kingdom",
    "United Republic of Tanzania" = "Tanzania",
    "United States of America" = "United States",
    "US Virgin Islands" = "Virgin Islands (U.S.)",
    "Venezuela (Bolivarian Republic of)" = "Venezuela, RB",
    "Yemen" = "Yemen, Rep.",
    "The Former Yugoslav Republic of Macedonia" = "North Macedonia",
    "West Bank and Gaza Strip" = "West Bank and Gaza",
    "China, Hong Kong SAR" = "Hong Kong SAR, China",
    "China, Macao SAR" = "Macao SAR, China"
  ))

# %%
glimpse(who_tidy)
# Out:
# Rows: 76,046
# Columns: 6
# $ country <chr> "Afghanistan", "Afghanistan", "Afghanistan", "Afghanistan", "A…
# $ year    <dbl> 1997, 1997, 1997, 1997, 1997, 1997, 1997, 1997, 1997, 1997, 19…
# $ type    <chr> "sp", "sp", "sp", "sp", "sp", "sp", "sp", "sp", "sp", "sp", "s…
# $ sex     <chr> "m", "m", "m", "m", "m", "m", "m", "f", "f", "f", "f", "f", "f…
# $ age     <chr> "014", "1524", "2534", "3544", "4554", "5564", "65", "014", "1…
# $ cases   <dbl> 0, 10, 6, 3, 5, 2, 0, 5, 38, 36, 14, 8, 0, 1, 30, 129, 128, 90…

# %% [markdown]
# **3.3 Join Datasets**
#
#   3.3.1 Identify the variable(s) required to join who_tidy and population_tidy.
#   - The variables required to join who_tidy and population_tidy:
#       - country
#       - year
#
#   3.3.2 Rename columns as needed to align variable names between datasets.
#   - This was address on the previous steps
#
#   3.3.3 Join the datasets into a tibble called tuberculosis.

# %%
tuberculosis <- who_tidy %>%
  inner_join(population_tidy, by = c("country", "year"))
head(tuberculosis)
# Out:
#   country     year type sex age  cases Country Code Indicator Name
# 1 Afghanistan 1997 sp   m   014   0    AFG          Population, total
# 2 Afghanistan 1997 sp   m   1524 10    AFG          Population, total
# 3 Afghanistan 1997 sp   m   2534  6    AFG          Population, total
# 4 Afghanistan 1997 sp   m   3544  3    AFG          Population, total
# 5 Afghanistan 1997 sp   m   4554  5    AFG          Population, total
# 6 Afghanistan 1997 sp   m   5564  2    AFG          Population, total
#   Indicator Code population
# 1 SP.POP.TOTL    18452091
# 2 SP.POP.TOTL    18452091
# 3 SP.POP.TOTL    18452091
# 4 SP.POP.TOTL    18452091
# 5 SP.POP.TOTL    18452091
# 6 SP.POP.TOTL    18452091

# %% [markdown]
# **3.4 Clean Up Data**
#
#   3.4.1 Remove unnecessary variables from tuberculosis.
#
#   3.4.2 Filter out rows with NA values.
#
#   3.4.3 Save the cleaned data back into tuberculosis.

# %%
tuberculosis <- tuberculosis %>%
  filter(!is.na(cases), !is.na(population))
tuberculosis
# Out:
#       country     year type sex age  cases Country Code Indicator Name
# 1     Afghanistan 1997 sp   m   014    0   AFG          Population, total
# 2     Afghanistan 1997 sp   m   1524  10   AFG          Population, total
# 3     Afghanistan 1997 sp   m   2534   6   AFG          Population, total
# 4     Afghanistan 1997 sp   m   3544   3   AFG          Population, total
# 5     Afghanistan 1997 sp   m   4554   5   AFG          Population, total
# 6     Afghanistan 1997 sp   m   5564   2   AFG          Population, total
# 7     Afghanistan 1997 sp   m   65     0   AFG          Population, total
# 8     Afghanistan 1997 sp   f   014    5   AFG          Population, total
# 9     Afghanistan 1997 sp   f   1524  38   AFG          Population, total
# 10    Afghanistan 1997 sp   f   2534  36   AFG          Population, total
# 11    Afghanistan 1997 sp   f   3544  14   AFG          Population, total
# 12    Afghanistan 1997 sp   f   4554   8   AFG          Population, total
# 13    Afghanistan 1997 sp   f   5564   0   AFG          Population, total
# 14    Afghanistan 1997 sp   f   65     1   AFG          Population, total
# 15    Afghanistan 1998 sp   m   014   30   AFG          Population, total
# 16    Afghanistan 1998 sp   m   1524 129   AFG          Population, total
# 17    Afghanistan 1998 sp   m   2534 128   AFG          Population, total
# 18    Afghanistan 1998 sp   m   3544  90   AFG          Population, total
# 19    Afghanistan 1998 sp   m   4554  89   AFG          Population, total
# 20    Afghanistan 1998 sp   m   5564  64   AFG          Population, total
# 21    Afghanistan 1998 sp   m   65    41   AFG          Population, total
# 22    Afghanistan 1998 sp   f   014   45   AFG          Population, total
# 23    Afghanistan 1998 sp   f   1524 350   AFG          Population, total
# 24    Afghanistan 1998 sp   f   2534 419   AFG          Population, total
# 25    Afghanistan 1998 sp   f   3544 194   AFG          Population, total
# 26    Afghanistan 1998 sp   f   4554 118   AFG          Population, total
# 27    Afghanistan 1998 sp   f   5564  61   AFG          Population, total
# 28    Afghanistan 1998 sp   f   65    20   AFG          Population, total
# 29    Afghanistan 1999 sp   m   014    8   AFG          Population, total
# 30    Afghanistan 1999 sp   m   1524  55   AFG          Population, total
# ⋮     ⋮           ⋮    ⋮    ⋮   ⋮    ⋮     ⋮            ⋮
# 73016 Zimbabwe    2012 sn   f   5564  516  ZWE          Population, total
# 73017 Zimbabwe    2012 sn   f   65    432  ZWE          Population, total
# 73018 Zimbabwe    2012 ep   m   014   233  ZWE          Population, total
# 73019 Zimbabwe    2012 ep   m   1524  214  ZWE          Population, total
# 73020 Zimbabwe    2012 ep   m   2534  658  ZWE          Population, total
# 73021 Zimbabwe    2012 ep   m   3544  789  ZWE          Population, total
# 73022 Zimbabwe    2012 ep   m   4554  331  ZWE          Population, total
# 73023 Zimbabwe    2012 ep   m   5564  178  ZWE          Population, total
# 73024 Zimbabwe    2012 ep   m   65    182  ZWE          Population, total
# 73025 Zimbabwe    2012 ep   f   014   208  ZWE          Population, total
# 73026 Zimbabwe    2012 ep   f   1524  319  ZWE          Population, total
# 73027 Zimbabwe    2012 ep   f   2534  710  ZWE          Population, total
# 73028 Zimbabwe    2012 ep   f   3544  579  ZWE          Population, total
# 73029 Zimbabwe    2012 ep   f   4554  228  ZWE          Population, total
# 73030 Zimbabwe    2012 ep   f   5564  140  ZWE          Population, total
# 73031 Zimbabwe    2012 ep   f   65    143  ZWE          Population, total
# 73032 Zimbabwe    2013 rel  m   014  1315  ZWE          Population, total
# 73033 Zimbabwe    2013 rel  m   1524 1642  ZWE          Population, total
# 73034 Zimbabwe    2013 rel  m   2534 5331  ZWE          Population, total
# 73035 Zimbabwe    2013 rel  m   3544 5363  ZWE          Population, total
# 73036 Zimbabwe    2013 rel  m   4554 2349  ZWE          Population, total
# 73037 Zimbabwe    2013 rel  m   5564 1206  ZWE          Population, total
# 73038 Zimbabwe    2013 rel  m   65   1208  ZWE          Population, total
# 73039 Zimbabwe    2013 rel  f   014  1252  ZWE          Population, total
# 73040 Zimbabwe    2013 rel  f   1524 2069  ZWE          Population, total
# 73041 Zimbabwe    2013 rel  f   2534 4649  ZWE          Population, total
# 73042 Zimbabwe    2013 rel  f   3544 3526  ZWE          Population, total
# 73043 Zimbabwe    2013 rel  f   4554 1453  ZWE          Population, total
# 73044 Zimbabwe    2013 rel  f   5564  811  ZWE          Population, total
# 73045 Zimbabwe    2013 rel  f   65    725  ZWE          Population, total
#       Indicator Code population
# 1     SP.POP.TOTL    18452091
# 2     SP.POP.TOTL    18452091
# 3     SP.POP.TOTL    18452091
# 4     SP.POP.TOTL    18452091
# 5     SP.POP.TOTL    18452091
# 6     SP.POP.TOTL    18452091
# 7     SP.POP.TOTL    18452091
# 8     SP.POP.TOTL    18452091
# 9     SP.POP.TOTL    18452091
# 10    SP.POP.TOTL    18452091
# 11    SP.POP.TOTL    18452091
# 12    SP.POP.TOTL    18452091
# 13    SP.POP.TOTL    18452091
# 14    SP.POP.TOTL    18452091
# 15    SP.POP.TOTL    19159996
# 16    SP.POP.TOTL    19159996
# 17    SP.POP.TOTL    19159996
# 18    SP.POP.TOTL    19159996
# 19    SP.POP.TOTL    19159996
# 20    SP.POP.TOTL    19159996
# 21    SP.POP.TOTL    19159996
# 22    SP.POP.TOTL    19159996
# 23    SP.POP.TOTL    19159996
# 24    SP.POP.TOTL    19159996
# 25    SP.POP.TOTL    19159996
# 26    SP.POP.TOTL    19159996
# 27    SP.POP.TOTL    19159996
# 28    SP.POP.TOTL    19159996
# 29    SP.POP.TOTL    19887785
# 30    SP.POP.TOTL    19887785
# ⋮     ⋮              ⋮
# 73016 SP.POP.TOTL    13817887
# 73017 SP.POP.TOTL    13817887
# 73018 SP.POP.TOTL    13817887
# 73019 SP.POP.TOTL    13817887
# 73020 SP.POP.TOTL    13817887
# 73021 SP.POP.TOTL    13817887
# 73022 SP.POP.TOTL    13817887
# 73023 SP.POP.TOTL    13817887
# 73024 SP.POP.TOTL    13817887
# 73025 SP.POP.TOTL    13817887
# 73026 SP.POP.TOTL    13817887
# 73027 SP.POP.TOTL    13817887
# 73028 SP.POP.TOTL    13817887
# 73029 SP.POP.TOTL    13817887
# 73030 SP.POP.TOTL    13817887
# 73031 SP.POP.TOTL    13817887
# 73032 SP.POP.TOTL    14013808
# 73033 SP.POP.TOTL    14013808
# 73034 SP.POP.TOTL    14013808
# 73035 SP.POP.TOTL    14013808
# 73036 SP.POP.TOTL    14013808
# 73037 SP.POP.TOTL    14013808
# 73038 SP.POP.TOTL    14013808
# 73039 SP.POP.TOTL    14013808
# 73040 SP.POP.TOTL    14013808
# 73041 SP.POP.TOTL    14013808
# 73042 SP.POP.TOTL    14013808
# 73043 SP.POP.TOTL    14013808
# 73044 SP.POP.TOTL    14013808
# 73045 SP.POP.TOTL    14013808

# %% [markdown]
# **4. Data Manipulation**

# %% [markdown]
#   4.1 Determine the total TB cases among men and women in the 21st century in the United States. Identify which sex had more cases.

# %%
us_21st <- tuberculosis %>%
  filter(country == "United States", year >= 2000) %>%
  group_by(sex) %>%
  summarise(total_cases = sum(cases))

us_21st

more_cases_sex <- us_21st$sex[which.max(us_21st$total_cases)]

cat("The sex that had more TB cases is:", ifelse(more_cases_sex == "m", "Men", "Women"))
# Out:
#   sex total_cases
# 1 f   45768
# 2 m   77867
# The sex that had more TB cases is: Men

# %% [markdown]
#   4.2 Create a new variable, cases_per_100k, representing TB cases per 100,000 people by year, sex, age group, and TB type.
#
#   4.3 Identify:
# - The country and year with the highest cases per 100k.
# - The country and year with the lowest cases per 100k.

# %%
tuberculosis <- tuberculosis %>%
  mutate(cases_per_100k = (cases / population) * 100000)

# Highest and Lowest
highest_rate <- tuberculosis %>% slice_max(cases_per_100k, n = 1)
lowest_rate <- tuberculosis %>% slice_min(cases_per_100k, n = 1)

highest_rate
# Out:
#   country year type sex age cases Country Code Indicator Name    Indicator Code
# 1 Samoa   2009 sp   f   65  1111  WSM          Population, total SP.POP.TOTL
#   population cases_per_100k
# 1 191513     580.1173

# %% [markdown]
# **5. Data Visualization**
#
# 5.1 Plot the total cases per 100k as a function of year for China, India, and the United States:
# - Use a log scale on the y-axis (scale_y_log10()).
# - Describe emerging patterns.
#
# 5.2 Compare distributions of total cases per 100k (summed over years, sexes, and TB types) across age groups:
#
# - Use a log scale on the y-axis.
# - Highlight observed patterns.
#
# 5.3 Create a plot to evaluate whether the number of cases per 100k in 2000 was related to a country’s population:
#
#
# Conclude based on the visualization.

# %%
tuberculosis %>%
  filter(country %in% c("China", "India", "United States of America")) %>%
  group_by(country, year) %>%
  summarise(total_rate = sum(cases_per_100k)) %>%
  ggplot(aes(x = year, y = total_rate, color = country)) +
  geom_line() +
  scale_y_log10() +
  labs(title = "TB Rates Over Time", y = "Cases per 100k (Log Scale)")
# Out:
# `summarise()` has grouped output by 'country'. You can override using the
# `.groups` argument.
# plot without title

# %%
ggplot(tuberculosis, aes(x = age, y = cases_per_100k)) +
  geom_boxplot() +
  scale_y_log10() +
  labs(title = "TB Distribution by Age Group")
# Out:
# Warning message in scale_y_log10():
# “log-10 transformation introduced infinite values.”
# Warning message:
# “Removed 8977 rows containing non-finite outside the scale range
# (`stat_boxplot()`).”
# plot without title

# %%
tuberculosis %>%
  filter(year == 2000) %>%
  group_by(country, population) %>%
  summarise(total_rate = sum(cases_per_100k)) %>%
  ggplot(aes(x = population, y = total_rate)) +
  geom_point(alpha = 0.5) +
  scale_x_log10() +
  scale_y_log10() +
  geom_smooth(method = "lm")
# Out:
# `summarise()` has grouped output by 'country'. You can override using the
# `.groups` argument.
# `geom_smooth()` using formula = 'y ~ x'
# plot without title

# %% [markdown]
# Typically, there isn't a strong linear correlation between a country's total population size and its TB rate (cases per 100k), as the rate is more heavily influenced by healthcare infrastructure and socioeconomic factors
